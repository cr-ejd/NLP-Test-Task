# %% [markdown]
# # Overview of the stuff I tried here

# %% [markdown]
# Here's an overview of what I've tried. Some of these things worked well, some of them didn't. I only left the code that's more or less useful.
#
# Stuff I tried:
# - using spaCy's matcher to define patterns for detecting specific entities (e.g., dimensions, prices, SKUs).
# - enhancing the entity detection by combining matcher results with spaCy’s default entity recognition.
# - deduplicating the entities to ensure each unique entity appears only once.
# - creating a custom dataset for fine-tuning a NER model, including sentences and entity annotations. Implemented a pipeline for fine-tuning a BERT model for NER tasks using the Hugging Face Transformers library. Defined the label list for various entities such as PRODUCT, BRAND, ORG, MATERIAL, and COLOR.
# - tried BERT, DistilBERT, Google Electra, Deberta, ALBERT. BERT and Google Electra gave me the best results. However, the solution is still far from perfect.
# - used Optuna to optimize hyperparameters of BERT

# %% [markdown]
# # DistilBERT

# %%
import re
import json
from transformers import pipeline
import torch

# Advanced text preprocessing function to remove irrelevant text and keep product-like sections
def preprocess_text(text):
    text = re.sub(r'(\b(Subscribe|Sign Up|Newsletter|Privacy|Terms|Customer Service)\b.*)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'(Magazine|Gift|Sweepstakes|Watch Now|Learn More|Sponsored)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\s+', ' ', text).strip()  # Remove excess whitespace
    return text

# Set up the device for inference (GPU/CPU)
device = 0 if torch.cuda.is_available() else -1

# Use a pre-trained NER model
model_name = "elastic/distilbert-base-cased-finetuned-conll03-english"
ner_model = pipeline("ner", model=model_name, aggregation_strategy="simple", device=device)

# Load the text file containing the scraped data
with open('/content/merged_scraped_data.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

# Preprocess the text to clean up redundant content
cleaned_text = preprocess_text(raw_text)

# Function to process text and extract product entities
def process_text(text):
    sections = re.split(r'URL:\s+(https?://[^\s]+)', text)
    structured_data = []

    for i in range(1, len(sections), 2):
        url = sections[i].strip()
        content = sections[i + 1].strip()

        # Apply the NER model to extract entities from the content
        entities = ner_model(content)

        # Filter product-like entities (keep "MISC", "ORG", "PER" for broader detection)
        product_entities = [
            {
                "word": entity['word'],
                "entity_group": entity['entity_group'],
                "confidence": float(entity['score'])  # Convert to float
            }
            for entity in entities
            if entity['entity_group'] in ['MISC', 'ORG', 'PER'] and entity['score'] > 0.6
        ]

        if product_entities:  # Only append if we found entities for this section
            structured_data.append({
                "URL": url,
                "products": product_entities
            })
        else:
            print(f"No entities found for URL: {url}")

    return structured_data

# Process the cleaned text and extract product-related information
structured_output = process_text(cleaned_text)

# Save the structured output to a JSON file
output_file = '/content/processed_final_data.json'
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(structured_output, f, ensure_ascii=False, indent=4)

# Print the structured output for verification
print(json.dumps(structured_output, ensure_ascii=False, indent=4))
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#                 "confidence": 0.844476580619812
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/HOUSE-Stackable-Organizer-Multifunctional-Combinations/dp/B0B62K55RV?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Black Nightstand",
#                 "entity_group": "ORG",
#                 "confidence": 0.9057246446609497
#             },
#             {
#                 "word": "Glass Shade",
#                 "entity_group": "ORG",
#                 "confidence": 0.6364215612411499
#             },
#             {
#                 "word": "Des",
#                 "entity_group": "ORG",
#                 "confidence": 0.6165320873260498
#             },
#             {
#                 "word": "##k Lamps",
#                 "entity_group": "ORG",
#                 "confidence": 0.6469679474830627
#             },
#             {
#                 "word": "##pps & Games Arts",
#                 "entity_group": "ORG",
#                 "confidence": 0.6084569692611694
#             },
#             {
#                 "word": "Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.7667205929756165
#             },
#             {
#                 "word": "Beauty & Personal Care",
#                 "entity_group": "ORG",
#                 "confidence": 0.8584727644920349
#             },
#             {
#                 "word": "CDs",
#                 "entity_group": "ORG",
#                 "confidence": 0.69581538438797
#             },
#             {
#                 "word": "Shoes",
#                 "entity_group": "ORG",
#                 "confidence": 0.9686513543128967
#             },
#             {
#                 "word": "& Jewelry Women Men Girls Boys",
#                 "entity_group": "ORG",
#                 "confidence": 0.6782366037368774
#             },
#             {
#                 "word": "Garden & Outdoor",
#                 "entity_group": "ORG",
#                 "confidence": 0.7424426078796387
#             },
#             {
#                 "word": "& Gour",
#                 "entity_group": "ORG",
#                 "confidence": 0.670325517654419
#             },
#             {
#                 "word": "Household & Baby Care Home & Business Services",
#                 "entity_group": "ORG",
#                 "confidence": 0.7884889841079712
#             },
#             {
#                 "word": "Home & Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.6987563967704773
#             },
#             {
#                 "word": "& Scientific",
#                 "entity_group": "ORG",
#                 "confidence": 0.7686847448348999
#             },
#             {
#                 "word": "##age",
#                 "entity_group": "ORG",
#                 "confidence": 0.6458798050880432
#             },
#             {
#                 "word": "Wine & Spirits",
#                 "entity_group": "ORG",
#                 "confidence": 0.7773549556732178
#             },
#             {
#                 "word": "Movies & TV",
#                 "entity_group": "ORG",
#                 "confidence": 0.7154770493507385
#             },
#             {
#                 "word": "Software So",
#                 "entity_group": "ORG",
#                 "confidence": 0.6304594874382019
#             },
#             {
#                 "word": "##usa",
#                 "entity_group": "ORG",
#                 "confidence": 0.6039400696754456
#             },
#             {
#                 "word": "Wine & Liquors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8033414483070374
#             },
#             {
#                 "word": "& Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.7294511198997498
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/Allewie-Platform-Upholstered-Headboard-Foundation/dp/B086M58PQ3?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Fu",
#                 "entity_group": "PER",
#                 "confidence": 0.9820548892021179
#             },
#             {
#                 "word": "##rn",
#                 "entity_group": "PER",
#                 "confidence": 0.9820423722267151
#             },
#             {
#                 "word": "##ule",
#                 "entity_group": "PER",
#                 "confidence": 0.9862821698188782
#             },
#             {
#                 "word": "##m White",
#                 "entity_group": "PER",
#                 "confidence": 0.7581058144569397
#             },
#             {
#                 "word": "V",
#                 "entity_group": "PER",
#                 "confidence": 0.7580100297927856
#             },
#             {
#                 "word": "##ert",
#                 "entity_group": "PER",
#                 "confidence": 0.615834653377533
#             },
#             {
#                 "word": "Storage",
#                 "entity_group": "ORG",
#                 "confidence": 0.6403577327728271
#             },
#             {
#                 "word": "##ab",
#                 "entity_group": "PER",
#                 "confidence": 0.9294394254684448
#             },
#             {
#                 "word": "##ric Dresser",
#                 "entity_group": "PER",
#                 "confidence": 0.7297513484954834
#             },
#             {
#                 "word": "##room",
#                 "entity_group": "PER",
#                 "confidence": 0.8768616318702698
#             },
#             {
#                 "word": "Hall",
#                 "entity_group": "PER",
#                 "confidence": 0.9726888537406921
#             },
#             {
#                 "word": "##way",
#                 "entity_group": "PER",
#                 "confidence": 0.9891318678855896
#             },
#             {
#                 "word": "Entry",
#                 "entity_group": "PER",
#                 "confidence": 0.9672362804412842
#             },
#             {
#                 "word": "##way",
#                 "entity_group": "PER",
#                 "confidence": 0.9739421010017395
#             },
#             {
#                 "word": "Nurse",
#                 "entity_group": "PER",
#                 "confidence": 0.892150342464447
#             },
#             {
#                 "word": "##ry",
#                 "entity_group": "PER",
#                 "confidence": 0.7536767721176147
#             },
#             {
#                 "word": "Nights",
#                 "entity_group": "ORG",
#                 "confidence": 0.9222047924995422
#             },
#             {
#                 "word": "##d",
#                 "entity_group": "ORG",
#                 "confidence": 0.6133941411972046
#             },
#             {
#                 "word": "St",
#                 "entity_group": "ORG",
#                 "confidence": 0.9475907683372498
#             },
#             {
#                 "word": "##ur",
#                 "entity_group": "ORG",
#                 "confidence": 0.7887062430381775
#             },
#             {
#                 "word": "##dy Steel Frame",
#                 "entity_group": "ORG",
#                 "confidence": 0.8665684461593628
#             },
#             {
#                 "word": "##pps",
#                 "entity_group": "ORG",
#                 "confidence": 0.9300845861434937
#             },
#             {
#                 "word": "& Games Arts,",
#                 "entity_group": "ORG",
#                 "confidence": 0.6477226614952087
#             },
#             {
#                 "word": "Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.8814524412155151
#             },
#             {
#                 "word": "Bartell",
#                 "entity_group": "PER",
#                 "confidence": 0.7498798966407776
#             },
#             {
#                 "word": "' s",
#                 "entity_group": "ORG",
#                 "confidence": 0.6692553758621216
#             },
#             {
#                 "word": "Beauty & Personal Care Books",
#                 "entity_group": "ORG",
#                 "confidence": 0.9174254536628723
#             },
#             {
#                 "word": "CDs & Vinyl Cell Phones & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.6655128598213196
#             },
#             {
#                 "word": "##lothing",
#                 "entity_group": "ORG",
#                 "confidence": 0.692315936088562
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys",
#                 "entity_group": "ORG",
#                 "confidence": 0.6931247115135193
#             },
#             {
#                 "word": "& Gourmet Food",
#                 "entity_group": "ORG",
#                 "confidence": 0.7357133626937866
#             },
#             {
#                 "word": "##made Health,",
#                 "entity_group": "ORG",
#                 "confidence": 0.6525211334228516
#             },
#             {
#                 "word": "Household & Baby Care Home & Business Services",
#                 "entity_group": "ORG",
#                 "confidence": 0.9011116027832031
#             },
#             {
#                 "word": "Home & Kitchen Industrial & Scientific Just",
#                 "entity_group": "ORG",
#                 "confidence": 0.7795295119285583
#             },
#             {
#                 "word": "##ottle Kindle Store Lazy Acres Natural Market",
#                 "entity_group": "ORG",
#                 "confidence": 0.7326676845550537
#             },
#             {
#                 "word": "##ggage & Travel",
#                 "entity_group": "ORG",
#                 "confidence": 0.6453428268432617
#             },
#             {
#                 "word": "Stores",
#                 "entity_group": "ORG",
#                 "confidence": 0.7035149335861206
#             },
#             {
#                 "word": "Metropolitan Market Mission",
#                 "entity_group": "ORG",
#                 "confidence": 0.6755072474479675
#             },
#             {
#                 "word": "Wine & Spirits Movies & TV",
#                 "entity_group": "ORG",
#                 "confidence": 0.777690589427948
#             },
#             {
#                 "word": "Instruments New Seasons Market Office Products Pet Food Express Pet",
#                 "entity_group": "ORG",
#                 "confidence": 0.7257704734802246
#             },
#             {
#                 "word": "Mart Smart Home Software Sousa '",
#                 "entity_group": "ORG",
#                 "confidence": 0.8312768340110779
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.844476580619812
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/Length-Mirror-Frameless-Bedroom-Mounted/dp/B092746858?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Z",
#                 "entity_group": "ORG",
#                 "confidence": 0.876084566116333
#             },
#             {
#                 "word": "&",
#                 "entity_group": "ORG",
#                 "confidence": 0.8336739540100098
#             },
#             {
#                 "word": "L",
#                 "entity_group": "ORG",
#                 "confidence": 0.8764553070068359
#             },
#             {
#                 "word": "S",
#                 "entity_group": "PER",
#                 "confidence": 0.6861822605133057
#             },
#             {
#                 "word": "##hoe Rack",
#                 "entity_group": "PER",
#                 "confidence": 0.7094327807426453
#             },
#             {
#                 "word": "Close",
#                 "entity_group": "PER",
#                 "confidence": 0.6462659239768982
#             },
#             {
#                 "word": "St",
#                 "entity_group": "ORG",
#                 "confidence": 0.6714763641357422
#             },
#             {
#                 "word": "##ack",
#                 "entity_group": "ORG",
#                 "confidence": 0.668141782283783
#             },
#             {
#                 "word": "##able Shoes",
#                 "entity_group": "ORG",
#                 "confidence": 0.7356219291687012
#             },
#             {
#                 "word": "Ba",
#                 "entity_group": "PER",
#                 "confidence": 0.9612471461296082
#             },
#             {
#                 "word": "##mbo",
#                 "entity_group": "PER",
#                 "confidence": 0.9594975709915161
#             },
#             {
#                 "word": "Combinations",
#                 "entity_group": "MISC",
#                 "confidence": 0.7702662944793701
#             },
#             {
#                 "word": "Home & Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.6158795952796936
#             },
#             {
#                 "word": "Medical Amazon Pharmacy",
#                 "entity_group": "ORG",
#                 "confidence": 0.6175768971443176
#             },
#             {
#                 "word": "##pps",
#                 "entity_group": "ORG",
#                 "confidence": 0.9228504300117493
#             },
#             {
#                 "word": "& Games Arts, Crafts & Sewing Audible Books & Originals",
#                 "entity_group": "ORG",
#                 "confidence": 0.7279666662216187
#             },
#             {
#                 "word": "Bart",
#                 "entity_group": "PER",
#                 "confidence": 0.7080528736114502
#             },
#             {
#                 "word": "' s",
#                 "entity_group": "ORG",
#                 "confidence": 0.6432735323905945
#             },
#             {
#                 "word": "Beauty & Personal Care Books Bristol",
#                 "entity_group": "ORG",
#                 "confidence": 0.8849287629127502
#             },
#             {
#                 "word": "CDs",
#                 "entity_group": "ORG",
#                 "confidence": 0.6778514385223389
#             },
#             {
#                 "word": "Phones & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.6824809312820435
#             },
#             {
#                 "word": "##lothing",
#                 "entity_group": "ORG",
#                 "confidence": 0.6963351964950562
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys",
#                 "entity_group": "ORG",
#                 "confidence": 0.727229118347168
#             },
#             {
#                 "word": "Music Electronics",
#                 "entity_group": "ORG",
#                 "confidence": 0.6582852602005005
#             },
#             {
#                 "word": "& Outdoor",
#                 "entity_group": "ORG",
#                 "confidence": 0.6176016330718994
#             },
#             {
#                 "word": "& Gourmet Food",
#                 "entity_group": "ORG",
#                 "confidence": 0.7322207689285278
#             },
#             {
#                 "word": "##made Health, Household & Baby Care Home & Business Services Home & Kitchen Industrial & Scientific Just",
#                 "entity_group": "ORG",
#                 "confidence": 0.8480565547943115
#             },
#             {
#                 "word": "##ottle Kindle Store Lazy Acres Natural Market Lucky Luggage & Travel Gear",
#                 "entity_group": "ORG",
#                 "confidence": 0.7703864574432373
#             },
#             {
#                 "word": "##xury Stores",
#                 "entity_group": "ORG",
#                 "confidence": 0.7267050743103027
#             },
#             {
#                 "word": "Wine & Spirits",
#                 "entity_group": "ORG",
#                 "confidence": 0.8402831554412842
#             },
#             {
#                 "word": "Movies & TV",
#                 "entity_group": "ORG",
#                 "confidence": 0.7304482460021973
#             },
#             {
#                 "word": "Instruments New Seasons Market Office Products Pet Food Express Pet",
#                 "entity_group": "ORG",
#                 "confidence": 0.7604855298995972
#             },
#             {
#                 "word": "Mart",
#                 "entity_group": "ORG",
#                 "confidence": 0.6191853284835815
#             },
#             {
#                 "word": "Home Software Sousa '",
#                 "entity_group": "ORG",
#                 "confidence": 0.7807626724243164
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8747023344039917
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/Allewie-Platform-Headboard-Upholstered-Foundation/dp/B08J7T5RVM?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Mobile",
#                 "entity_group": "ORG",
#                 "confidence": 0.7282642722129822
#             },
#             {
#                 "word": "Computer Desk",
#                 "entity_group": "ORG",
#                 "confidence": 0.7412550449371338
#             },
#             {
#                 "word": "Port",
#                 "entity_group": "ORG",
#                 "confidence": 0.7544829845428467
#             },
#             {
#                 "word": "##pps",
#                 "entity_group": "ORG",
#                 "confidence": 0.7709096074104309
#             },
#             {
#                 "word": "Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.774146318435669
#             },
#             {
#                 "word": "Bartell",
#                 "entity_group": "ORG",
#                 "confidence": 0.6441783905029297
#             },
#             {
#                 "word": "Beauty & Personal Care",
#                 "entity_group": "ORG",
#                 "confidence": 0.8702394366264343
#             },
#             {
#                 "word": "CDs",
#                 "entity_group": "ORG",
#                 "confidence": 0.7551945447921753
#             },
#             {
#                 "word": "& Vinyl Cell Phones & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.6814360022544861
#             },
#             {
#                 "word": "Shoes",
#                 "entity_group": "ORG",
#                 "confidence": 0.973484992980957
#             },
#             {
#                 "word": "& Jewelry Women",
#                 "entity_group": "ORG",
#                 "confidence": 0.7383280992507935
#             },
#             {
#                 "word": "Household & Baby Care Home & Business Services",
#                 "entity_group": "ORG",
#                 "confidence": 0.6903207898139954
#             },
#             {
#                 "word": "&",
#                 "entity_group": "ORG",
#                 "confidence": 0.6412540078163147
#             },
#             {
#                 "word": "Wine & Spirits",
#                 "entity_group": "ORG",
#                 "confidence": 0.825815737247467
#             },
#             {
#                 "word": "Movies & TV",
#                 "entity_group": "ORG",
#                 "confidence": 0.7828443050384521
#             },
#             {
#                 "word": "Software Sousa",
#                 "entity_group": "ORG",
#                 "confidence": 0.7016798853874207
#             },
#             {
#                 "word": "Wine & Liquors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8601686954498291
#             },
#             {
#                 "word": "& Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.6857133507728577
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/LIKIMIO-Charging-Station-Nightstand-Drawers/dp/B0D78GBP37?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Full Body",
#                 "entity_group": "ORG",
#                 "confidence": 0.651959240436554
#             },
#             {
#                 "word": "Home & Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.6581358313560486
#             },
#             {
#                 "word": "Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.8237186670303345
#             },
#             {
#                 "word": "##ble Books & Original",
#                 "entity_group": "ORG",
#                 "confidence": 0.6126154661178589
#             },
#             {
#                 "word": "Beauty & Personal Care Books",
#                 "entity_group": "ORG",
#                 "confidence": 0.9215596914291382
#             },
#             {
#                 "word": "Bristol Farms",
#                 "entity_group": "ORG",
#                 "confidence": 0.6047315001487732
#             },
#             {
#                 "word": "##s & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.6404545307159424
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys Baby",
#                 "entity_group": "ORG",
#                 "confidence": 0.8897045850753784
#             },
#             {
#                 "word": "##s & Fine",
#                 "entity_group": "ORG",
#                 "confidence": 0.6845868229866028
#             },
#             {
#                 "word": "Digital Music Electronics",
#                 "entity_group": "ORG",
#                 "confidence": 0.6032729744911194
#             },
#             {
#                 "word": "##me Garden & Outdoor",
#                 "entity_group": "ORG",
#                 "confidence": 0.6245244741439819
#             },
#             {
#                 "word": "Health, Household & Baby Care Home & Business Services Home & Kitchen Industrial & Scientific Just",
#                 "entity_group": "ORG",
#                 "confidence": 0.8313056230545044
#             },
#             {
#                 "word": "Kindle Store",
#                 "entity_group": "ORG",
#                 "confidence": 0.7505159974098206
#             },
#             {
#                 "word": "##gg",
#                 "entity_group": "ORG",
#                 "confidence": 0.6308858394622803
#             },
#             {
#                 "word": "##age & Travel Gear Luxury Stores",
#                 "entity_group": "ORG",
#                 "confidence": 0.6906066536903381
#             },
#             {
#                 "word": "Metropolitan Market Mission",
#                 "entity_group": "ORG",
#                 "confidence": 0.6952154040336609
#             },
#             {
#                 "word": "Wine & Spirits Movies & TV Musical Instruments New Seasons Market Office Products",
#                 "entity_group": "ORG",
#                 "confidence": 0.7522959113121033
#             },
#             {
#                 "word": "Mart Smart Home Software Sousa",
#                 "entity_group": "ORG",
#                 "confidence": 0.8954992294311523
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8589102625846863
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/SHA-CERLIN-Upholstered-Ergonomics-Headboard/dp/B0BSNWTZ2S?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "All",
#                 "entity_group": "PER",
#                 "confidence": 0.9865195751190186
#             },
#             {
#                 "word": "##ew",
#                 "entity_group": "PER",
#                 "confidence": 0.9899508357048035
#             },
#             {
#                 "word": "##ie",
#                 "entity_group": "PER",
#                 "confidence": 0.9679048657417297
#             },
#             {
#                 "word": "Matt",
#                 "entity_group": "ORG",
#                 "confidence": 0.9961291551589966
#             },
#             {
#                 "word": "##ress Foundation",
#                 "entity_group": "ORG",
#                 "confidence": 0.9886007308959961
#             },
#             {
#                 "word": "Wood",
#                 "entity_group": "ORG",
#                 "confidence": 0.8567242622375488
#             },
#             {
#                 "word": "##en",
#                 "entity_group": "ORG",
#                 "confidence": 0.9730413556098938
#             },
#             {
#                 "word": "Slats",
#                 "entity_group": "PER",
#                 "confidence": 0.6311882734298706
#             },
#             {
#                 "word": "Home & Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.6374132037162781
#             },
#             {
#                 "word": "Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.8045714497566223
#             },
#             {
#                 "word": "& Original",
#                 "entity_group": "ORG",
#                 "confidence": 0.6335604190826416
#             },
#             {
#                 "word": "Beauty & Personal Care Books",
#                 "entity_group": "ORG",
#                 "confidence": 0.9100480079650879
#             },
#             {
#                 "word": "##s & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.6299303770065308
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys Baby",
#                 "entity_group": "ORG",
#                 "confidence": 0.8450865745544434
#             },
#             {
#                 "word": "& Fine",
#                 "entity_group": "ORG",
#                 "confidence": 0.7781263589859009
#             },
#             {
#                 "word": "Digital Music Electronics",
#                 "entity_group": "ORG",
#                 "confidence": 0.6134324073791504
#             },
#             {
#                 "word": "##me Garden & Outdoor",
#                 "entity_group": "ORG",
#                 "confidence": 0.6472587585449219
#             },
#             {
#                 "word": "Health, Household & Baby Care Home & Business Services Home & Kitchen Industrial & Scientific",
#                 "entity_group": "ORG",
#                 "confidence": 0.8383036851882935
#             },
#             {
#                 "word": "Kindle Store",
#                 "entity_group": "ORG",
#                 "confidence": 0.7497542500495911
#             },
#             {
#                 "word": "##gg",
#                 "entity_group": "ORG",
#                 "confidence": 0.6233958005905151
#             },
#             {
#                 "word": "##age & Travel Gear Luxury Stores",
#                 "entity_group": "ORG",
#                 "confidence": 0.680237889289856
#             },
#             {
#                 "word": "Metropolitan Market Mission",
#                 "entity_group": "ORG",
#                 "confidence": 0.6840360164642334
#             },
#             {
#                 "word": "Wine & Spirits Movies & TV Musical Instruments New Seasons Market Office Products",
#                 "entity_group": "ORG",
#                 "confidence": 0.733418345451355
#             },
#             {
#                 "word": "Mart Smart Home Software Sousa",
#                 "entity_group": "ORG",
#                 "confidence": 0.8643496632575989
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8344537615776062
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/Yaheetech-Upholstered-Platform-Headboard-Foundation/dp/B0CKBDS6NC?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Cha",
#                 "entity_group": "ORG",
#                 "confidence": 0.8889915943145752
#             },
#             {
#                 "word": "##rg",
#                 "entity_group": "ORG",
#                 "confidence": 0.9269501566886902
#             },
#             {
#                 "word": "##ing",
#                 "entity_group": "ORG",
#                 "confidence": 0.8666765093803406
#             },
#             {
#                 "word": "Modern Black Nightstand",
#                 "entity_group": "ORG",
#                 "confidence": 0.9721733331680298
#             },
#             {
#                 "word": "LED",
#                 "entity_group": "ORG",
#                 "confidence": 0.6481643915176392
#             },
#             {
#                 "word": "Bed",
#                 "entity_group": "ORG",
#                 "confidence": 0.885388195514679
#             },
#             {
#                 "word": "##side",
#                 "entity_group": "ORG",
#                 "confidence": 0.7603783011436462
#             },
#             {
#                 "word": "Home & Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.8097057342529297
#             },
#             {
#                 "word": "Amazon",
#                 "entity_group": "ORG",
#                 "confidence": 0.6183682084083557
#             },
#             {
#                 "word": "##pps",
#                 "entity_group": "ORG",
#                 "confidence": 0.6504642367362976
#             },
#             {
#                 "word": "Games",
#                 "entity_group": "ORG",
#                 "confidence": 0.7604255080223083
#             },
#             {
#                 "word": "Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.7988014817237854
#             },
#             {
#                 "word": "##ell",
#                 "entity_group": "PER",
#                 "confidence": 0.6326172947883606
#             },
#             {
#                 "word": "Beauty & Personal Care Books",
#                 "entity_group": "ORG",
#                 "confidence": 0.9441641569137573
#             },
#             {
#                 "word": "CDs",
#                 "entity_group": "ORG",
#                 "confidence": 0.8750728964805603
#             },
#             {
#                 "word": "& Vinyl",
#                 "entity_group": "ORG",
#                 "confidence": 0.6218389272689819
#             },
#             {
#                 "word": "##s & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.7320927977561951
#             },
#             {
#                 "word": "##lot",
#                 "entity_group": "ORG",
#                 "confidence": 0.6519768238067627
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys",
#                 "entity_group": "ORG",
#                 "confidence": 0.8822413682937622
#             },
#             {
#                 "word": "##s & Fine Art",
#                 "entity_group": "ORG",
#                 "confidence": 0.6623338460922241
#             },
#             {
#                 "word": "Music Electronics",
#                 "entity_group": "ORG",
#                 "confidence": 0.6583735942840576
#             },
#             {
#                 "word": "Garden & Outdoor Cards",
#                 "entity_group": "ORG",
#                 "confidence": 0.6746922731399536
#             },
#             {
#                 "word": "##cery & Gourmet Food Handmade Health, Household & Baby Care Home & Business Services",
#                 "entity_group": "ORG",
#                 "confidence": 0.7994815707206726
#             },
#             {
#                 "word": "Home & Kitchen Industrial & Scientific",
#                 "entity_group": "ORG",
#                 "confidence": 0.6161727905273438
#             },
#             {
#                 "word": "##g",
#                 "entity_group": "ORG",
#                 "confidence": 0.6362533569335938
#             },
#             {
#                 "word": "##le Kindle Store",
#                 "entity_group": "ORG",
#                 "confidence": 0.6736459732055664
#             },
#             {
#                 "word": "Metropolitan Market Mission",
#                 "entity_group": "ORG",
#                 "confidence": 0.6082995533943176
#             },
#             {
#                 "word": "Wine & Spirits",
#                 "entity_group": "ORG",
#                 "confidence": 0.9098944664001465
#             },
#             {
#                 "word": "Movies & TV Musical Instruments",
#                 "entity_group": "ORG",
#                 "confidence": 0.7427669763565063
#             },
#             {
#                 "word": "Seasons Market Office Products",
#                 "entity_group": "ORG",
#                 "confidence": 0.689927875995636
#             },
#             {
#                 "word": "Food Express",
#                 "entity_group": "ORG",
#                 "confidence": 0.6102536916732788
#             },
#             {
#                 "word": "Smart Home Software Sousa",
#                 "entity_group": "ORG",
#                 "confidence": 0.6223297715187073
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8000929951667786
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/Industrial-Table-Lamps-Bedrooms-Set/dp/B0C3CMG9D8/?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "##lf Re",
#                 "entity_group": "PER",
#                 "confidence": 0.6255488991737366
#             },
#             {
#                 "word": "Tall Wood",
#                 "entity_group": "ORG",
#                 "confidence": 0.8160146474838257
#             },
#             {
#                 "word": "U",
#                 "entity_group": "ORG",
#                 "confidence": 0.8004958629608154
#             },
#             {
#                 "word": "##tility",
#                 "entity_group": "ORG",
#                 "confidence": 0.9246187210083008
#             },
#             {
#                 "word": "Living Room",
#                 "entity_group": "ORG",
#                 "confidence": 0.87005215883255
#             },
#             {
#                 "word": "& Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.7635334730148315
#             },
#             {
#                 "word": "Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.8004671335220337
#             },
#             {
#                 "word": "Beauty & Personal Care Books",
#                 "entity_group": "ORG",
#                 "confidence": 0.8638797998428345
#             },
#             {
#                 "word": "Bristol Farms",
#                 "entity_group": "ORG",
#                 "confidence": 0.6022874712944031
#             },
#             {
#                 "word": "##s & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.6387850046157837
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys Baby",
#                 "entity_group": "ORG",
#                 "confidence": 0.8346817493438721
#             },
#             {
#                 "word": "##ibles & Fine Art",
#                 "entity_group": "ORG",
#                 "confidence": 0.612103283405304
#             },
#             {
#                 "word": "##hyme Garden & Outdoor",
#                 "entity_group": "ORG",
#                 "confidence": 0.6829928159713745
#             },
#             {
#                 "word": "& Gourmet",
#                 "entity_group": "ORG",
#                 "confidence": 0.6452233791351318
#             },
#             {
#                 "word": "Household & Baby Care Home & Business Services",
#                 "entity_group": "ORG",
#                 "confidence": 0.8779333829879761
#             },
#             {
#                 "word": "Home & Kitchen Industrial & Scientific Just",
#                 "entity_group": "ORG",
#                 "confidence": 0.7517633438110352
#             },
#             {
#                 "word": "##age &",
#                 "entity_group": "ORG",
#                 "confidence": 0.6231093406677246
#             },
#             {
#                 "word": "##x",
#                 "entity_group": "ORG",
#                 "confidence": 0.6635224223136902
#             },
#             {
#                 "word": "##ury Stores",
#                 "entity_group": "ORG",
#                 "confidence": 0.7603528499603271
#             },
#             {
#                 "word": "Metropolitan Market Mission",
#                 "entity_group": "ORG",
#                 "confidence": 0.659520149230957
#             },
#             {
#                 "word": "Wine & Spirits Movies & TV Musical Instruments",
#                 "entity_group": "ORG",
#                 "confidence": 0.8268892765045166
#             },
#             {
#                 "word": "Seasons Market Office Products",
#                 "entity_group": "ORG",
#                 "confidence": 0.7226982712745667
#             },
#             {
#                 "word": "Food Express",
#                 "entity_group": "ORG",
#                 "confidence": 0.7253642082214355
#             },
#             {
#                 "word": "Mart Smart Home Software Sousa",
#                 "entity_group": "ORG",
#                 "confidence": 0.8869430422782898
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8317281007766724
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/walmart-miranda-lambert-wanda-june-fall-collection-2024-8718353",
#         "products": [
#             {
#                 "word": "Ya",
#                 "entity_group": "ORG",
#                 "confidence": 0.9570204019546509
#             },
#             {
#                 "word": "##hee",
#                 "entity_group": "ORG",
#                 "confidence": 0.9593391418457031
#             },
#             {
#                 "word": "##tech",
#                 "entity_group": "ORG",
#                 "confidence": 0.9387910962104797
#             },
#             {
#                 "word": "Wood",
#                 "entity_group": "PER",
#                 "confidence": 0.6434314846992493
#             },
#             {
#                 "word": "Matt",
#                 "entity_group": "ORG",
#                 "confidence": 0.7921971678733826
#             },
#             {
#                 "word": "##ress Foundation",
#                 "entity_group": "ORG",
#                 "confidence": 0.7408347129821777
#             },
#             {
#                 "word": "Light Gray",
#                 "entity_group": "ORG",
#                 "confidence": 0.689315676689148
#             },
#             {
#                 "word": "Home & Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.6150700449943542
#             },
#             {
#                 "word": "##pps",
#                 "entity_group": "ORG",
#                 "confidence": 0.7210745811462402
#             },
#             {
#                 "word": "Arts, Crafts & Sewing",
#                 "entity_group": "ORG",
#                 "confidence": 0.6827893257141113
#             },
#             {
#                 "word": "Bartell",
#                 "entity_group": "ORG",
#                 "confidence": 0.8837411403656006
#             },
#             {
#                 "word": "Beauty & Personal Care",
#                 "entity_group": "ORG",
#                 "confidence": 0.8616952896118164
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys",
#                 "entity_group": "ORG",
#                 "confidence": 0.7675889730453491
#             },
#             {
#                 "word": "& Fine Art",
#                 "entity_group": "ORG",
#                 "confidence": 0.7460575103759766
#             },
#             {
#                 "word": "##s",
#                 "entity_group": "ORG",
#                 "confidence": 0.687034547328949
#             },
#             {
#                 "word": "Music Electronics",
#                 "entity_group": "ORG",
#                 "confidence": 0.8006365895271301
#             },
#             {
#                 "word": "##me Garden & Outdoor Cards",
#                 "entity_group": "ORG",
#                 "confidence": 0.6649405360221863
#             },
#             {
#                 "word": "& Gourmet",
#                 "entity_group": "ORG",
#                 "confidence": 0.6498216986656189
#             },
#             {
#                 "word": "Health, Household & Baby Care Home & Business Services",
#                 "entity_group": "ORG",
#                 "confidence": 0.7910911440849304
#             },
#             {
#                 "word": "Home & Kitchen Industrial & Scientific",
#                 "entity_group": "ORG",
#                 "confidence": 0.7202454209327698
#             },
#             {
#                 "word": "##x",
#                 "entity_group": "ORG",
#                 "confidence": 0.6102672219276428
#             },
#             {
#                 "word": "##ury Stores",
#                 "entity_group": "ORG",
#                 "confidence": 0.6768144965171814
#             },
#             {
#                 "word": "Metropolitan Market Mission",
#                 "entity_group": "ORG",
#                 "confidence": 0.647671639919281
#             },
#             {
#                 "word": "Wine & Spirits Movies & TV",
#                 "entity_group": "ORG",
#                 "confidence": 0.7961536049842834
#             },
#             {
#                 "word": "Mart Smart Home Software Sousa",
#                 "entity_group": "ORG",
#                 "confidence": 0.7994295954704285
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8557316660881042
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/Furnulem-Vertical-Organizer-Nightstand-Furniture/dp/B0BWY7NK35?th=1&tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Miranda Lambert",
#                 "entity_group": "PER",
#                 "confidence": 0.9933267831802368
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9749512076377869
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9743992686271667
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9930893182754517
#             }
#         ]
#     },
#     {
#         "URL": "https://www.amazon.com/Zinus-Olivia-Metal-Platform-Support/dp/B06WWF1P78?tag=people-onsite-backup-20",
#         "products": [
#             {
#                 "word": "Z",
#                 "entity_group": "ORG",
#                 "confidence": 0.876084566116333
#             },
#             {
#                 "word": "&",
#                 "entity_group": "ORG",
#                 "confidence": 0.8336739540100098
#             },
#             {
#                 "word": "L",
#                 "entity_group": "ORG",
#                 "confidence": 0.8764553070068359
#             },
#             {
#                 "word": "S",
#                 "entity_group": "PER",
#                 "confidence": 0.6861822605133057
#             },
#             {
#                 "word": "##hoe Rack",
#                 "entity_group": "PER",
#                 "confidence": 0.7094327807426453
#             },
#             {
#                 "word": "Close",
#                 "entity_group": "PER",
#                 "confidence": 0.6462659239768982
#             },
#             {
#                 "word": "St",
#                 "entity_group": "ORG",
#                 "confidence": 0.6714763641357422
#             },
#             {
#                 "word": "##ack",
#                 "entity_group": "ORG",
#                 "confidence": 0.668141782283783
#             },
#             {
#                 "word": "##able Shoes",
#                 "entity_group": "ORG",
#                 "confidence": 0.7356219291687012
#             },
#             {
#                 "word": "Ba",
#                 "entity_group": "PER",
#                 "confidence": 0.9612471461296082
#             },
#             {
#                 "word": "##mbo",
#                 "entity_group": "PER",
#                 "confidence": 0.9594975709915161
#             },
#             {
#                 "word": "Combinations",
#                 "entity_group": "MISC",
#                 "confidence": 0.7702662944793701
#             },
#             {
#                 "word": "Home & Kitchen",
#                 "entity_group": "ORG",
#                 "confidence": 0.6158795952796936
#             },
#             {
#                 "word": "Medical Amazon Pharmacy",
#                 "entity_group": "ORG",
#                 "confidence": 0.6175768971443176
#             },
#             {
#                 "word": "##pps",
#                 "entity_group": "ORG",
#                 "confidence": 0.9228504300117493
#             },
#             {
#                 "word": "& Games Arts, Crafts & Sewing Audible Books & Originals",
#                 "entity_group": "ORG",
#                 "confidence": 0.7279666662216187
#             },
#             {
#                 "word": "Bart",
#                 "entity_group": "PER",
#                 "confidence": 0.7080528736114502
#             },
#             {
#                 "word": "' s",
#                 "entity_group": "ORG",
#                 "confidence": 0.6432735323905945
#             },
#             {
#                 "word": "Beauty & Personal Care Books Bristol",
#                 "entity_group": "ORG",
#                 "confidence": 0.8849287629127502
#             },
#             {
#                 "word": "CDs",
#                 "entity_group": "ORG",
#                 "confidence": 0.6778514385223389
#             },
#             {
#                 "word": "Phones & Accessories",
#                 "entity_group": "ORG",
#                 "confidence": 0.6824809312820435
#             },
#             {
#                 "word": "##lothing",
#                 "entity_group": "ORG",
#                 "confidence": 0.6963351964950562
#             },
#             {
#                 "word": "Shoes & Jewelry Women Men Girls Boys",
#                 "entity_group": "ORG",
#                 "confidence": 0.727229118347168
#             },
#             {
#                 "word": "Music Electronics",
#                 "entity_group": "ORG",
#                 "confidence": 0.6582852602005005
#             },
#             {
#                 "word": "& Outdoor",
#                 "entity_group": "ORG",
#                 "confidence": 0.6176016330718994
#             },
#             {
#                 "word": "& Gourmet Food",
#                 "entity_group": "ORG",
#                 "confidence": 0.7322207689285278
#             },
#             {
#                 "word": "##made Health, Household & Baby Care Home & Business Services Home & Kitchen Industrial & Scientific Just",
#                 "entity_group": "ORG",
#                 "confidence": 0.8480565547943115
#             },
#             {
#                 "word": "##ottle Kindle Store Lazy Acres Natural Market Lucky Luggage & Travel Gear",
#                 "entity_group": "ORG",
#                 "confidence": 0.7703864574432373
#             },
#             {
#                 "word": "##xury Stores",
#                 "entity_group": "ORG",
#                 "confidence": 0.7267050743103027
#             },
#             {
#                 "word": "Wine & Spirits",
#                 "entity_group": "ORG",
#                 "confidence": 0.8402831554412842
#             },
#             {
#                 "word": "Movies & TV",
#                 "entity_group": "ORG",
#                 "confidence": 0.7304482460021973
#             },
#             {
#                 "word": "Instruments New Seasons Market Office Products Pet Food Express Pet",
#                 "entity_group": "ORG",
#                 "confidence": 0.7604855298995972
#             },
#             {
#                 "word": "Mart",
#                 "entity_group": "ORG",
#                 "confidence": 0.6191853284835815
#             },
#             {
#                 "word": "Home Software Sousa '",
#                 "entity_group": "ORG",
# ...
#                 "confidence": 0.7805541753768921
#             },
#             {
#                 "word": "Wine & Liquors Sports & Outdoors",
#                 "entity_group": "ORG",
#                 "confidence": 0.8635790944099426
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/best-amazon-october-prime-day-deals-live-8709014",
#         "products": [
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.975688099861145
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9757365584373474
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9943468570709229
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/amazon-october-prime-day-member-deals-2024-8708477",
#         "products": [
#             {
#                 "word": "Best Amazon",
#                 "entity_group": "MISC",
#                 "confidence": 0.6685715913772583
#             },
#             {
#                 "word": "##s",
#                 "entity_group": "MISC",
#                 "confidence": 0.6824101805686951
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9739497900009155
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9802958369255066
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9948699474334717
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/furniture-deals-amazon-prime-big-deal-days-2024-8708571",
#         "products": [
#             {
#                 "word": "Day",
#                 "entity_group": "MISC",
#                 "confidence": 0.6361787915229797
#             },
#             {
#                 "word": "Best",
#                 "entity_group": "MISC",
#                 "confidence": 0.9549888968467712
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9816628098487854
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9841359853744507
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9938583374023438
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/amazon-prime-big-deal-days-vacuum-deals-october-2024-8708516",
#         "products": [
#             {
#                 "word": "Day",
#                 "entity_group": "MISC",
#                 "confidence": 0.6479861736297607
#             },
#             {
#                 "word": "Amazon",
#                 "entity_group": "ORG",
#                 "confidence": 0.8835447430610657
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9861939549446106
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9894697666168213
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9969672560691833
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/amazon-prime-day-bissell-cleanview-xr-cordless-vacuum-deal-2024-8708574",
#         "products": [
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9855470657348633
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.984761118888855
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9950469732284546
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/shark-cordless-vacuum-deal-amazon-october-prime-day-2024-8708653",
#         "products": [
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.8964516520500183
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.8645328283309937
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9799067974090576
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/early-amazon-prime-day-vacuum-deals-october-2024-8723461",
#         "products": [
#             {
#                 "word": "B",
#                 "entity_group": "MISC",
#                 "confidence": 0.7265050411224365
#             },
#             {
#                 "word": "##isse",
#                 "entity_group": "MISC",
#                 "confidence": 0.8069179654121399
#             },
#             {
#                 "word": "##ll",
#                 "entity_group": "MISC",
#                 "confidence": 0.9054281711578369
#             },
#             {
#                 "word": "Co",
#                 "entity_group": "MISC",
#                 "confidence": 0.9375839829444885
#             },
#             {
#                 "word": "##rd",
#                 "entity_group": "MISC",
#                 "confidence": 0.9804603457450867
#             },
#             {
#                 "word": "##less Vacuum",
#                 "entity_group": "MISC",
#                 "confidence": 0.9300785064697266
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.6031763553619385
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.7803220748901367
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9530850052833557
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/best-amazon-prime-big-day-deals-dyson-deals-10-2024-8708519",
#         "products": [
#             {
#                 "word": "D",
#                 "entity_group": "PER",
#                 "confidence": 0.9509454965591431
#             },
#             {
#                 "word": "##ys",
#                 "entity_group": "PER",
#                 "confidence": 0.9916843175888062
#             },
#             {
#                 "word": "##on Owners",
#                 "entity_group": "PER",
#                 "confidence": 0.8801534175872803
#             },
#             {
#                 "word": "Reg",
#                 "entity_group": "PER",
#                 "confidence": 0.8778948187828064
#             },
#             {
#                 "word": "##ret",
#                 "entity_group": "PER",
#                 "confidence": 0.7551231980323792
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.846297025680542
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9031379222869873
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9723950624465942
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/early-amazon-october-prime-day-dyson-vacuum-deals-2024-8723034",
#         "products": [
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9891936182975769
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9877899885177612
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9957015514373779
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/joanna-gaines-magnolia-home-loloi-rugs-amazon-prime-big-deal-days-2024-8708603",
#         "products": [
#             {
#                 "word": "D",
#                 "entity_group": "PER",
#                 "confidence": 0.9990233182907104
#             },
#             {
#                 "word": "##ys",
#                 "entity_group": "PER",
#                 "confidence": 0.9993047714233398
#             },
#             {
#                 "word": "##on Vacuums",
#                 "entity_group": "PER",
#                 "confidence": 0.9992280006408691
#             },
#             {
#                 "word": "Air Purifiers",
#                 "entity_group": "ORG",
#                 "confidence": 0.9843438863754272
#             },
#             {
#                 "word": "More",
#                 "entity_group": "ORG",
#                 "confidence": 0.7695431709289551
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.8881998658180237
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.8115289807319641
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.982189416885376
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/amazon-october-prime-day-pyrex-food-storage-containers-deal-2024-8708648",
#         "products": [
#             {
#                 "word": "D",
#                 "entity_group": "PER",
#                 "confidence": 0.9935594797134399
#             },
#             {
#                 "word": "##ys",
#                 "entity_group": "PER",
#                 "confidence": 0.9975529313087463
#             },
#             {
#                 "word": "##on Vacuum",
#                 "entity_group": "PER",
#                 "confidence": 0.995383620262146
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9807528853416443
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9815876483917236
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9932053089141846
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/tiny-homes-amazon-october-2024-8708645",
#         "products": [
#             {
#                 "word": "Joanna Gaines",
#                 "entity_group": "PER",
#                 "confidence": 0.9985847473144531
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.8747154474258423
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9376959204673767
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9838991165161133
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/amazon-outlet-furniture-deals-september-2024-8719746",
#         "products": [
#             {
#                 "word": "P",
#                 "entity_group": "ORG",
#                 "confidence": 0.8036551475524902
#             },
#             {
#                 "word": "##yre",
#                 "entity_group": "ORG",
#                 "confidence": 0.6079400777816772
#             },
#             {
#                 "word": "##x Food Storage",
#                 "entity_group": "ORG",
#                 "confidence": 0.7933574914932251
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.8988208770751953
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9286859035491943
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9864815473556519
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/cozy-bedding-early-deals-amazon-prime-big-deal-days-2024-8722984",
#         "products": [
#             {
#                 "word": "Tiny Homes",
#                 "entity_group": "ORG",
#                 "confidence": 0.7442700266838074
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9793205261230469
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9830611348152161
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9953058362007141
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/martha-stewart-area-rug-deals-amazon-wayfair-september-2024-8720918",
#         "products": [
#             {
#                 "word": "##lling Comforters",
#                 "entity_group": "PER",
#                 "confidence": 0.8858023881912231
#             },
#             {
#                 "word": "Pi",
#                 "entity_group": "PER",
#                 "confidence": 0.9857679009437561
#             },
#             {
#                 "word": "##llow",
#                 "entity_group": "PER",
#                 "confidence": 0.9254907369613647
#             },
#             {
#                 "word": "##s",
#                 "entity_group": "PER",
#                 "confidence": 0.9351598024368286
#             },
#             {
#                 "word": "B",
#                 "entity_group": "PER",
#                 "confidence": 0.760880172252655
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.8356330990791321
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.8831315040588379
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9791247844696045
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/cpd35-luxury-prefabricated-round-tiny-home-amazon-october-2024-8721147",
#         "products": [
#             {
#                 "word": "Day",
#                 "entity_group": "MISC",
#                 "confidence": 0.6361787915229797
#             },
#             {
#                 "word": "Best",
#                 "entity_group": "MISC",
#                 "confidence": 0.9549888968467712
#             },
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9816628098487854
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9841359853744507
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9938583374023438
#             }
#         ]
#     },
#     {
#         "URL": "https://people.com/trending-home-and-kitchen-deals-amazon-october-2024-8721911",
#         "products": [
#             {
#                 "word": "Dot",
#                 "entity_group": "ORG",
#                 "confidence": 0.9721890687942505
#             },
#             {
#                 "word": "##das",
#                 "entity_group": "ORG",
#                 "confidence": 0.9761270880699158
#             },
#             {
#                 "word": "##h Meredith",
#                 "entity_group": "ORG",
#                 "confidence": 0.9940246343612671
#             }
#         ]
#     }
# ]

# %% [markdown]
# # Testing the model results on some sample sentences

# %%
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Check if GPU is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Tokenizer and Model Setup
model_name = "elastic/distilbert-base-cased-finetuned-conll03-english"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name).to(device)

# Initialize the NER pipeline using the loaded model and tokenizer
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple", device=0 if torch.cuda.is_available() else -1)

# Function to extract entities from input text
def extract_entities(text):
    entities = ner_pipeline(text)

    extracted_entities = []
    for entity in entities:
        extracted_entities.append({
            'word': entity['word'],
            'entity_group': entity['entity_group'],
            'confidence': entity['score']
        })
    return extracted_entities

# Test input text directly (replace this with your actual test data)
user_input = """
Novogratz Brittany Sofa Futon - Premium Linen Upholstery and Wooden Legs - Navy Blue

This 32-inch Philips Smart Roku TV has over 4,900 perfect ratings and is on sale at Walmart.
"""

# Extract entities and display results
results = extract_entities(user_input)

# Print the extracted entities
print("Extracted Entities:")
if results:
    for result in results:
        print(f"Word: {result['word']}, Entity Group: {result['entity_group']}, Confidence: {result['confidence']:.4f}")
else:
    print("No entities found.")
# Out:
# Extracted Entities:
# Word: Nov, Entity Group: ORG, Confidence: 0.9981
# Word: ##og, Entity Group: ORG, Confidence: 0.9978
# Word: ##rat, Entity Group: ORG, Confidence: 0.9921
# Word: ##z Brittany, Entity Group: ORG, Confidence: 0.7639
# Word: Sofa Futon, Entity Group: MISC, Confidence: 0.7157
# Word: Line, Entity Group: ORG, Confidence: 0.5919
# Word: ##n Upholstery, Entity Group: ORG, Confidence: 0.9297
# Word: Wood, Entity Group: ORG, Confidence: 0.9050
# Word: ##en, Entity Group: ORG, Confidence: 0.9386
# Word: Legs, Entity Group: PER, Confidence: 0.7280
# Word: Navy Blue, Entity Group: ORG, Confidence: 0.6799
# Word: Philips Smart Roku TV, Entity Group: MISC, Confidence: 0.8245
# Word: W, Entity Group: ORG, Confidence: 0.9975
# Word: ##al, Entity Group: ORG, Confidence: 0.9973
# Word: ##mart, Entity Group: ORG, Confidence: 0.9960

# %% [markdown]
# # Google Electra

# %%
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Check if GPU is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Tokenizer and Model Setup
model_name = "microsoft/deberta-v3-small"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name).to(device)

# Initialize the NER pipeline
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple", device=0 if torch.cuda.is_available() else -1)

# Function to post-process and combine WordPiece tokens
def combine_wordpieces(entities):
    combined_entities = []
    current_entity = {}

    for entity in entities:
        if entity['word'].startswith("##"):  # Continuation of a word
            current_entity['word'] += entity['word'][2:]
            current_entity['score'] = max(current_entity['score'], entity['score'])  # Keep highest confidence score
        else:
            if current_entity:  # Append previous entity if exists
                combined_entities.append(current_entity)
            current_entity = {
                'word': entity['word'],
                'entity_group': entity['entity_group'],
                'score': entity['score']
            }
    if current_entity:  # Add the last entity
        combined_entities.append(current_entity)

    return combined_entities

# Custom function to improve PRODUCT detection
def enhance_product_detection(entities):
    product_keywords = ['sofa', 'chair', 'table', 'futon', 'bed', 'tv', 'lamp', 'rug', 'ottoman', 'stool']

    for entity in entities:
        entity_lower = entity['word'].lower()
        if any(keyword in entity_lower for keyword in product_keywords):
            entity['entity_group'] = 'PRODUCT'  # Reclassify as PRODUCT if matching keywords

    return entities

# Full pipeline: Extract, combine tokens, enhance PRODUCT detection
def extract_entities(text):
    entities = ner_pipeline(text)
    combined_entities = combine_wordpieces(entities)
    enhanced_entities = enhance_product_detection(combined_entities)

    return enhanced_entities

# Example input text
user_input = """
We like the Branch Verve because it’s one of the most comfortable office chairs you can buy, plus it’s attractive and attainably priced.
Fitted with an adjustable seat, armrest and lumbar support, it comes with plenty of features to tailor it
to your comfort preferences and workspace. (We especially recommend the Branch Verve for
shorter people since the seat can be lowered to 16.5 inches.)
Those looking for an office chair with a headrest needn’t fret:
You can purchase one separately and in a color that matches your chair.
Another plus for the Branch Verve: It has a soft-knit back and is available in five sleek colors, making it a practical and beautiful addition to your office space.
"""

# Extract entities and display results
results = extract_entities(user_input)

# Print the extracted entities
print("Extracted Entities:")
if results:
    for result in results:
        print(f"Word: {result['word']}, Entity Group: {result['entity_group']}, Confidence: {result['score']:.4f}")
else:
    print("No entities found.")
# Out:
# Some weights of DebertaV2ForTokenClassification were not initialized from the model checkpoint at microsoft/deberta-v3-small and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Extracted Entities:
# Word: We like the, Entity Group: LABEL_1, Confidence: 0.6533
# Word: Branch, Entity Group: LABEL_0, Confidence: 0.5050
# Word: Verve because, Entity Group: LABEL_1, Confidence: 0.5484
# Word: it’s one of the most, Entity Group: LABEL_0, Confidence: 0.7570
# Word: comfortable, Entity Group: PRODUCT, Confidence: 0.6757
# Word: office chairs you can buy, plus it’s, Entity Group: PRODUCT, Confidence: 0.6191
# Word: attractive and attain, Entity Group: LABEL_1, Confidence: 0.6011
# Word: ably priced. Fitted with an adjustable seat,, Entity Group: PRODUCT, Confidence: 0.6974
# Word: armrest, Entity Group: LABEL_1, Confidence: 0.5313
# Word: and lumbar support,, Entity Group: LABEL_0, Confidence: 0.6082
# Word: it, Entity Group: LABEL_1, Confidence: 0.6365
# Word: comes with plenty of, Entity Group: LABEL_0, Confidence: 0.7404
# Word: features to tailor it, Entity Group: LABEL_1, Confidence: 0.5922
# Word: to your, Entity Group: LABEL_0, Confidence: 0.5676
# Word: comfort preferences, Entity Group: LABEL_1, Confidence: 0.6659
# Word: and, Entity Group: LABEL_0, Confidence: 0.5687
# Word: workspace, Entity Group: LABEL_1, Confidence: 0.7339
# Word: . (, Entity Group: LABEL_0, Confidence: 0.8009
# Word: We, Entity Group: LABEL_1, Confidence: 0.6579
# Word: especially recommend the Branch Verve, Entity Group: LABEL_0, Confidence: 0.5586
# Word: for shorter people, Entity Group: LABEL_1, Confidence: 0.6338
# Word: since, Entity Group: LABEL_0, Confidence: 0.6422
# Word: the seat can, Entity Group: LABEL_1, Confidence: 0.5960
# Word: be, Entity Group: LABEL_0, Confidence: 0.6372
# Word: lowered, Entity Group: LABEL_1, Confidence: 0.5130
# Word: to, Entity Group: LABEL_0, Confidence: 0.5800
# Word: 16, Entity Group: LABEL_1, Confidence: 0.5090
# Word: .5 inches.), Entity Group: LABEL_0, Confidence: 0.7724
# Word: Those looking, Entity Group: LABEL_1, Confidence: 0.5852
# Word: for an office chair with a, Entity Group: PRODUCT, Confidence: 0.6372
# Word: headrest, Entity Group: LABEL_1, Confidence: 0.6360
# Word: needn’t fret:, Entity Group: LABEL_0, Confidence: 0.6879
# Word: You can purchase one, Entity Group: LABEL_1, Confidence: 0.5820
# Word: separately, Entity Group: LABEL_0, Confidence: 0.5572
# Word: and, Entity Group: LABEL_1, Confidence: 0.7133
# Word: in a, Entity Group: LABEL_0, Confidence: 0.5359
# Word: color that, Entity Group: LABEL_1, Confidence: 0.5785
# Word: matches, Entity Group: LABEL_0, Confidence: 0.7456
# Word: your chair, Entity Group: PRODUCT, Confidence: 0.6752
# Word: ., Entity Group: LABEL_0, Confidence: 0.7178
# Word: Another plus, Entity Group: LABEL_1, Confidence: 0.5877
# Word: for the Branch, Entity Group: LABEL_0, Confidence: 0.5539
# Word: Verve, Entity Group: LABEL_1, Confidence: 0.5456
# Word: :, Entity Group: LABEL_0, Confidence: 0.5420
# Word: It, Entity Group: LABEL_1, Confidence: 0.7122
# Word: has a, Entity Group: LABEL_0, Confidence: 0.7428
# Word: soft, Entity Group: LABEL_1, Confidence: 0.5252
# Word: -, Entity Group: LABEL_0, Confidence: 0.9070
# Word: knit back and is, Entity Group: LABEL_1, Confidence: 0.6455
# Word: available in five, Entity Group: LABEL_0, Confidence: 0.6182
# Word: sleek colors, Entity Group: LABEL_1, Confidence: 0.7022
# Word: , making, Entity Group: LABEL_0, Confidence: 0.6225
# Word: it, Entity Group: LABEL_1, Confidence: 0.7227
# Word: a, Entity Group: LABEL_0, Confidence: 0.7303
# Word: practical, Entity Group: LABEL_1, Confidence: 0.6320
# Word: and, Entity Group: LABEL_0, Confidence: 0.5736
# Word: beautiful, Entity Group: LABEL_1, Confidence: 0.6976
# Word: addition to, Entity Group: LABEL_0, Confidence: 0.6757
# Word: your, Entity Group: LABEL_1, Confidence: 0.5891
# Word: office space., Entity Group: LABEL_0, Confidence: 0.5990

# %% [markdown]
# # BERT

# %%
import torch
from transformers import pipeline

# Load the pre-trained BERT-based NER model
ner_pipeline = pipeline("ner", model="dslim/bert-base-NER", aggregation_strategy="simple")

# Check if GPU is available and set device
device = "cuda" if torch.cuda.is_available() else "cpu"
# Example sentences with furniture-related descriptions
furniture_sentences = [
    "The Lincoln is a smart, Howard style sofa with a tight sprung back and curved arms.",
    "The Novogratz Brittany Sofa Futon comes with wooden legs and a sleek design, available in navy blue.",
    "This Phillips Smart Roku TV is on sale at Walmart.",
    "The sleek Barcelona collection includes leather chairs and elegant sofas with steel frames."
]

# Run NER on furniture sentences
for sentence in furniture_sentences:
    print(f"Sentence: {sentence}")
    entities = ner_pipeline(sentence)

    # Print each entity extracted by the model
    for entity in entities:
        print(f"Word: {entity['word']}, Entity: {entity['entity_group']}, Confidence: {entity['score']:.4f}")
    print("\n")  # Line break between sentences
# Out:
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Sentence: The Lincoln is a smart, Howard style sofa with a tight sprung back and curved arms.
# Word: Lincoln, Entity: MISC, Confidence: 0.7826
# Word: Howard, Entity: MISC, Confidence: 0.9721
#
#
# Sentence: The Novogratz Brittany Sofa Futon comes with wooden legs and a sleek design, available in navy blue.
# Word: Novogratz Brittany Sofa Futon, Entity: MISC, Confidence: 0.9687
#
#
# Sentence: This Phillips Smart Roku TV is on sale at Walmart.
# Word: Phillips Smart Roku TV, Entity: ORG, Confidence: 0.9775
# Word: Walmart, Entity: ORG, Confidence: 0.9847
#
#
# Sentence: The sleek Barcelona collection includes leather chairs and elegant sofas with steel frames.
# Word: Barcelona, Entity: LOC, Confidence: 0.9981

# %% [markdown]
# # Post-processing (might help to refine the outputs of NER models)

# %%
import re
from transformers import pipeline

# Load pre-trained NER pipeline
ner_pipeline = pipeline("ner", model="dslim/bert-base-NER", aggregation_strategy="simple", device=0)

# Define a list of furniture-related keywords for post-processing
furniture_keywords = [
    "sofa", "futon", "table", "chair", "bed", "couch", "ottoman", "dresser",
    "desk", "cabinet", "shelf", "recliner", "bench", "armchair", "nightstand", "wardrobe"
]

# Function to refine NER results with keyword matching
def refine_ner_results(text, entities):
    refined_entities = []
    # Extract NER results from the pipeline
    for entity in entities:
        refined_entities.append({
            'word': entity['word'],
            'entity': entity['entity_group'],
            'confidence': entity['score']
        })

    # Keyword-based post-processing: mark product-related keywords as 'PRODUCT'
    for keyword in furniture_keywords:
        if re.search(rf"\b{keyword}\b", text, re.IGNORECASE):
            refined_entities.append({
                'word': keyword,
                'entity': 'PRODUCT',
                'confidence': 1.0  # High confidence for manual rule
            })

    return refined_entities

# Test sentences
furniture_sentences = [
    "The Lincoln is a smart, Howard style sofa with a tight sprung back and curved arms.",
    "The Novogratz Brittany Sofa Futon comes with wooden legs and a sleek design, available in navy blue.",
    "Floating Shelves for Wall, Wall Mounted Rustic Wood Shelves for Bathroom, Bedroom, Living Room, Kitchen, Hanging Shelf for Books/Storage/Room Decor with 22lbs Capacity (Black, Set of 3, 16in)",
    "That’s why we recommend the Sayl chair from Herman Miller for remote workers with back pain. Built with a unique seat back made from flexible elastomer, the Sayl excels at supporting spine alignment. Plus you can add adjustable lumbar support (for an extra cost).."
]

# Run NER and post-process results
for sentence in furniture_sentences:
    print(f"Sentence: {sentence}")
    entities = ner_pipeline(sentence)
    refined_entities = refine_ner_results(sentence, entities)

    # Print results
    for entity in refined_entities:
        print(f"Word: {entity['word']}, Entity: {entity['entity']}, Confidence: {entity['confidence']:.4f}")
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Sentence: The Lincoln is a smart, Howard style sofa with a tight sprung back and curved arms.
# Word: Lincoln, Entity: MISC, Confidence: 0.7826
# Word: Howard, Entity: MISC, Confidence: 0.9721
# Word: sofa, Entity: PRODUCT, Confidence: 1.0000
#
#
# Sentence: The Novogratz Brittany Sofa Futon comes with wooden legs and a sleek design, available in navy blue.
# Word: Novogratz Brittany Sofa Futon, Entity: MISC, Confidence: 0.9687
# Word: sofa, Entity: PRODUCT, Confidence: 1.0000
# Word: futon, Entity: PRODUCT, Confidence: 1.0000
#
#
# Sentence: Floating Shelves for Wall, Wall Mounted Rustic Wood Shelves for Bathroom, Bedroom, Living Room, Kitchen, Hanging Shelf for Books/Storage/Room Decor with 22lbs Capacity (Black, Set of 3, 16in)
# Word: She, Entity: ORG, Confidence: 0.6082
# Word: Wall, Entity: LOC, Confidence: 0.9378
# Word: Wall, Entity: LOC, Confidence: 0.3936
# Word: Mounted Rustic, Entity: MISC, Confidence: 0.7980
# Word: Bathroom, Entity: LOC, Confidence: 0.9069
# Word: Bedroom, Entity: LOC, Confidence: 0.9069
# Word: Living Room, Entity: LOC, Confidence: 0.9049
# Word: Kitchen, Entity: LOC, Confidence: 0.8074
# Word: Hanging Shelf, Entity: LOC, Confidence: 0.9070
# Word: Books, Entity: LOC, Confidence: 0.7334
# Word: ##orage, Entity: LOC, Confidence: 0.5596
# Word: Dec, Entity: LOC, Confidence: 0.4711
# Word: shelf, Entity: PRODUCT, Confidence: 1.0000
#
#
# Sentence: That’s why we recommend the Sayl chair from Herman Miller for remote workers with back pain. Built with a unique seat back made from flexible elastomer, the Sayl excels at supporting spine alignment. Plus you can add adjustable lumbar support (for an extra cost)..
# Word: Sayl, Entity: ORG, Confidence: 0.6656
# Word: Herman Miller, Entity: PER, Confidence: 0.9988
# Word: Sayl, Entity: ORG, Confidence: 0.7489
# Word: chair, Entity: PRODUCT, Confidence: 1.0000

# %% [markdown]
# # Finetuning BERT with a small custom furniture dataset

# %%
from datasets import load_dataset, DatasetDict

# Load your dataset from the CSV file
dataset = load_dataset("csv", data_files="/content/furniture_ner_dataset.csv")

# Split dataset into train and validation sets (e.g., 80% train, 20% validation)
train_test_split = dataset['train'].train_test_split(test_size=0.2)
dataset = DatasetDict({
    'train': train_test_split['train'],
    'validation': train_test_split['test'],
})

# %%
import ast
import torch
import pandas as pd
from datasets import load_dataset, DatasetDict
from transformers import AutoTokenizer, AutoModelForTokenClassification, Trainer, TrainingArguments, DataCollatorForTokenClassification

# Load custom dataset
dataset = load_dataset("csv", data_files="/content/furniture_ner_dataset.csv")

# Split dataset into train and validation sets
train_test_split = dataset['train'].train_test_split(test_size=0.2)
dataset = DatasetDict({
    'train': train_test_split['train'],
    'validation': train_test_split['test'],
})

# Define label list
label_list = ["O", "PRODUCT", "BRAND", "ORG", "MATERIAL", "COLOR"]

# Load the tokenizer and model
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))

# Function to parse entity string into a structured format
def parse_entities(entities):
    try:
        # The input format seems to be a string representation of a list, we need to parse it
        entities = ast.literal_eval(entities)
        return [(entity['start'], entity['end'], entity['label']) for entity in entities]
    except (ValueError, SyntaxError, KeyError):
        return []  # Return an empty list if parsing fails

# Tokenization and label alignment function
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["sentence"], truncation=True, is_split_into_words=False, padding=True)

    labels = []
    for i, entity_data in enumerate(examples["entities"]):
        entities = parse_entities(entity_data)
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        label_ids = [-100] * len(tokenized_inputs["input_ids"][i])  # Initialize labels as -100 for special tokens

        # Assign labels for each word based on entity spans
        for start, end, label in entities:
            for word_idx in range(len(word_ids)):
                # Check if token position is in entity range
                if word_ids[word_idx] is not None and word_ids[word_idx] >= start and word_ids[word_idx] < end:
                    label_ids[word_idx] = label_list.index(label)

        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# Apply the tokenization and alignment
tokenized_datasets = dataset.map(tokenize_and_align_labels, batched=True, remove_columns=dataset["train"].column_names)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    save_total_limit=1,
    load_best_model_at_end=True,
    logging_dir="./logs"
)

# Trainer setup
data_collator = DataCollatorForTokenClassification(tokenizer)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator
)

# Fine-tune the model
trainer.train()
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/17 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.566775</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.382329</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.302040</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6, training_loss=1.4264589945475261, metrics={'train_runtime': 34.3747, 'train_samples_per_second': 1.484, 'train_steps_per_second': 0.175, 'total_flos': 598656601332.0, 'train_loss': 1.4264589945475261, 'epoch': 3.0})

# %%
from transformers import AutoModelForTokenClassification, AutoTokenizer, Trainer, TrainingArguments
from datasets import load_dataset

# Load your dataset
# Make sure your dataset has a 'tokens' and 'ner_tags' field
dataset = load_dataset('your_dataset')  # Replace with your dataset path

# Load pre-trained BERT model and tokenizer
model_name = "bert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))

# Tokenization and alignment function
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples['tokens'], truncation=True, is_split_into_words=True)
    labels = []
    for i, label in enumerate(examples['ner_tags']):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)
    tokenized_inputs['labels'] = labels
    return tokenized_inputs

# Tokenize and align your dataset
tokenized_datasets = dataset.map(tokenize_and_align_labels, batched=True)

# Set training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    save_total_limit=2,
    save_steps=10_000
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    data_collator=DataCollatorForTokenClassification(tokenizer),
)

# Fine-tune the model
trainer.train()

# Save the model
trainer.save_model("./fine-tuned-bert-product-ner")

# %%
# Example furniture sentences after fine-tuning
furniture_sentences = [
    "The Lincoln is a smart, Howard style sofa with a tight sprung back and curved arms.",
    "The Novogratz Brittany Sofa Futon comes with wooden legs and a sleek design, available in navy blue.",
    "This Phillips Smart Roku TV is on sale at Walmart.",
    "The sleek Barcelona collection includes leather chairs and elegant sofas with steel frames."
]

# Run NER on the sentences
for sentence in furniture_sentences:
    print(f"Sentence: {sentence}")
    entities = ner_pipeline(sentence)
    for entity in entities:
        print(f"Word: {entity['word']}, Entity: {entity['entity_group']}, Confidence: {entity['score']:.4f}")
    print("\n")
